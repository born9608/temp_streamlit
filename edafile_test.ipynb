# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

from eda import abal_data_eda

# %%
df_abal = abal_data_eda('../data/abalone.csv')
df_abal
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
columns_list = df_abal.columns.to_list()
columns_list
# Out:
# ['Sex',
#  'Length',
#  'Diameter',
#  'Height',
#  'Whole weight',
#  'Shucked weight',
#  'Viscera weight',
#  'Shell weight',
#  'Rings']

# %%
color = sns.color_palette()
color[1]
# Out:
# (1.0, 0.4980392156862745, 0.054901960784313725)

# %%
sns.color_palette("Paired")
# Out:
# [(0.6509803921568628, 0.807843137254902, 0.8901960784313725),
#  (0.12156862745098039, 0.47058823529411764, 0.7058823529411765),
#  (0.6980392156862745, 0.8745098039215686, 0.5411764705882353),
#  (0.2, 0.6274509803921569, 0.17254901960784313),
#  (0.984313725490196, 0.6039215686274509, 0.6),
#  (0.8901960784313725, 0.10196078431372549, 0.10980392156862745),
#  (0.9921568627450981, 0.7490196078431373, 0.43529411764705883),
#  (1.0, 0.4980392156862745, 0.0),
#  (0.792156862745098, 0.6980392156862745, 0.8392156862745098),
#  (0.41568627450980394, 0.23921568627450981, 0.6039215686274509),
#  (1.0, 1.0, 0.6),
#  (0.6941176470588235, 0.34901960784313724, 0.1568627450980392)]

# %%
df_star = pd.read_csv('../data/star.csv')

# %%
df_star
# Out:
#         Mean of the integrated profile  \
# 0                           140.562500
# 1                           102.507812
# 2                           103.015625
# 3                           136.750000
# 4                            88.726562
# ...                                ...
# 17893                       136.429688
# 17894                       122.554688
# 17895                       119.335938
# 17896                       114.507812
# 17897                        57.062500
#
#         Standard deviation of the integrated profile  \
# 0                                          55.683782
# 1                                          58.882430
# 2                                          39.341649
# 3                                          57.178449
# 4                                          40.672225
# ...                                              ...
# 17893                                      59.847421
# 17894                                      49.485605
# ...

# %%
df_star.columns.to_list()
# Out:
# [' Mean of the integrated profile',
#  ' Standard deviation of the integrated profile',
#  ' Excess kurtosis of the integrated profile',
#  ' Skewness of the integrated profile',
#  ' Mean of the DM-SNR curve',
#  ' Standard deviation of the DM-SNR curve',
#  ' Excess kurtosis of the DM-SNR curve',
#  ' Skewness of the DM-SNR curve',
#  'target_class']

# %%
df_star['target_class'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df_star['target_class'].value_counts(normalize=True)
# Out:
# 0    0.908426
# 1    0.091574
# Name: target_class, dtype: float64

# %%
# 독립 변수 목록
features = df_star.columns.to_list()

plt.figure()
box_plot = sns.boxplot(x='target_class', y=' Mean of the integrated profile', data=df_star)
box_plot.set_xticklabels(['Not Pulsar', 'Pulsar'])
plt.show()
